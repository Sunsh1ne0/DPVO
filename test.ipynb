# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.load('trajectory_plots/result.npy')

# %%
plt.figure(figsize=(10, 10))
plt.plot(data[:, 0], data[:, 1], 'o')
